# %%
第十二章 pandas高级应用

# %%
pandas的分类类型

# %%
import numpy as np; import pandas as pd
values = pd.Series(['apple', 'orange', 'apple','apple'] * 2)
values
# Out:
# 0     apple
# 1    orange
# 2     apple
# 3     apple
# 4     apple
# 5    orange
# 6     apple
# 7     apple
# dtype: object

# %%
pd.unique(values)
# Out:
# array(['apple', 'orange'], dtype=object)

# %%
pd.value_counts(values)
# Out:
# apple     6
# orange    2
# dtype: int64

# %%
values = pd.Series([0, 1, 0, 0] * 2)
values
# Out:
# 0    0
# 1    1
# 2    0
# 3    0
# 4    0
# 5    1
# 6    0
# 7    0
# dtype: int64

# %%
pd.unique(values)
# Out:
# array([0, 1], dtype=int64)

# %%
pd.value_counts(values)
# Out:
# 0    6
# 1    2
# dtype: int64

# %%
values = pd.Series([0, 1, 0, 0] * 2)
dim = pd.Series(['apple', 'orange'])
values
# Out:
# 0    0
# 1    1
# 2    0
# 3    0
# 4    0
# 5    1
# 6    0
# 7    0
# dtype: int64

# %%
dim
# Out:
# 0     apple
# 1    orange
# dtype: object

# %%
dim.take(values)
# Out:
# 0     apple
# 1    orange
# 0     apple
# 0     apple
# 0     apple
# 1    orange
# 0     apple
# 0     apple
# dtype: object

# %%
对分类进行转换。一些相对简单的转变例子包括：
重命名分类。
加入一个新的分类，不改变已经存在的分类的顺序或位置。

# %%
pandas的分类类型

# %%
fruits = ['apple', 'orange', 'apple', 'apple'] * 2
N = len(fruits)
df = pd.DataFrame({'fruit': fruits,'basket_id': np.arange(N),'count': np.random.randint(3, 15,
size=N),'weight': np.random.uniform(0, 4,size=N)},columns=['basket_id', 'fruit', 'count','weight'])
df
# Out:
#    basket_id   fruit  count    weight
# 0          0   apple      5  1.883228
# 1          1  orange     14  1.727127
# 2          2   apple      5  1.461816
# 3          3   apple     13  0.461339
# 4          4   apple      8  0.294347
# 5          5  orange      3  0.325242
# 6          6   apple      7  0.938005
# 7          7   apple      8  0.904282

# %%
df['fruit']是一个Python字符串对象的数组

# %%
fruit_cat = df['fruit'].astype('category')
fruit_cat
# Out:
# 0     apple
# 1    orange
# 2     apple
# 3     apple
# 4     apple
# 5    orange
# 6     apple
# 7     apple
# Name: fruit, dtype: category
# Categories (2, object): [apple, orange]

# %%
fruit_cat的值不是NumPy数组，而是一个pandas.Categorical实例：

# %%
fruit_cat.values
# Out:
# [apple, orange, apple, apple, apple, orange, apple, apple]
# Categories (2, object): [apple, orange]

# %%
c = fruit_cat.values
type(c)
# Out:
# pandas.core.arrays.categorical.Categorical

# %%
c.categories
# Out:
# Index(['apple', 'orange'], dtype='object')

# %%
c.codes
# Out:
# array([0, 1, 0, 0, 0, 1, 0, 0], dtype=int8)

# %%
df['fruit'] = df['fruit'].astype('category')
df.fruit
# Out:
# 0     apple
# 1    orange
# 2     apple
# 3     apple
# 4     apple
# 5    orange
# 6     apple
# 7     apple
# Name: fruit, dtype: category
# Categories (2, object): [apple, orange]

# %%
my_categories = pd.Categorical(['foo', 'bar', 'baz', 'foo',
'bar'])
my_categories
# Out:
# [foo, bar, baz, foo, bar]
# Categories (3, object): [bar, baz, foo]

# %%
categories = ['foo', 'bar', 'baz']
codes = [0, 1, 2, 0, 0, 1]
my_cats_2 = pd.Categorical.from_codes(codes, categories)
my_cats_2
# Out:
# [foo, bar, baz, foo, foo, bar]
# Categories (3, object): [foo, bar, baz]

# %%
ordered_cat = pd.Categorical.from_codes(codes, categories,ordered=True)
ordered_cat
# Out:
# [foo, bar, baz, foo, foo, bar]
# Categories (3, object): [foo < bar < baz]

# %%
my_cats_2.as_ordered()
# Out:
# [foo, bar, baz, foo, foo, bar]
# Categories (3, object): [foo < bar < baz]

# %%
最后要注意，分类数据不需要字符串，尽管我仅仅展示了字符串的例子。分类数组
可以包括任意不可变类型。
用分类进行计算
与非编码版本（比如字符串数组）相比，使用pandas的Categorical有些类似。某
些pandas组件，比如groupby函数，更适合进行分类。还有一些函数可以使用有
序标志位。

# %%
np.random.seed(12345)
draws = np.random.randn(1000)
draws
# Out:
# array([-2.04707659e-01,  4.78943338e-01, -5.19438715e-01, -5.55730304e-01,
#         1.96578057e+00,  1.39340583e+00,  9.29078767e-02,  2.81746153e-01,
#         7.69022568e-01,  1.24643474e+00,  1.00718936e+00, -1.29622111e+00,
#         2.74991633e-01,  2.28912879e-01,  1.35291684e+00,  8.86429341e-01,
#        -2.00163731e+00, -3.71842537e-01,  1.66902531e+00, -4.38569736e-01,
#        -5.39741446e-01,  4.76985010e-01,  3.24894392e+00, -1.02122752e+00,
#        -5.77087303e-01,  1.24121276e-01,  3.02613562e-01,  5.23772068e-01,
#         9.40277775e-04,  1.34380979e+00, -7.13543985e-01, -8.31153539e-01,
#        -2.37023165e+00, -1.86076079e+00, -8.60757398e-01,  5.60145293e-01,
#        -1.26593449e+00,  1.19827125e-01, -1.06351245e+00,  3.32882716e-01,
#        -2.35941881e+00, -1.99542955e-01, -1.54199553e+00, -9.70735912e-01,
#        -1.30703025e+00,  2.86349747e-01,  3.77984111e-01, -7.53886535e-01,
# ...

# %%
np.random.seed(12345)
draws = np.random.randn(1000)
draws[:5]
# Out:
# array([-0.20470766,  0.47894334, -0.51943872, -0.5557303 ,  1.96578057])

# %%
bins = pd.qcut(draws, 4)
bins
# Out:
# [(-0.684, -0.0101], (-0.0101, 0.63], (-0.684, -0.0101], (-0.684, -0.0101], (0.63, 3.928], ..., (-0.0101, 0.63], (-0.684, -0.0101], (-2.9499999999999997, -0.684], (-0.0101, 0.63], (0.63, 3.928]]
# Length: 1000
# Categories (4, interval[float64]): [(-2.9499999999999997, -0.684] < (-0.684, -0.0101] < (-0.0101, 0.63] < (0.63, 3.928]]

# %%
bins = pd.qcut(draws, 4, labels=['Q1', 'Q2', 'Q3', 'Q4'])
bins
# Out:
# [Q2, Q3, Q2, Q2, Q4, ..., Q3, Q2, Q1, Q3, Q4]
# Length: 1000
# Categories (4, object): [Q1 < Q2 < Q3 < Q4]

# %%
bins.codes[:10]
# Out:
# array([1, 2, 1, 1, 3, 3, 2, 2, 3, 3], dtype=int8)

# %%
bins = pd.Series(bins, name='quartile')
results = (pd.Series(draws).groupby(bins).agg(['count', 'min', 'max']).reset_index())
results
# Out:
#   quartile  count       min       max
# 0       Q1    250 -2.949343 -0.685484
# 1       Q2    250 -0.683066 -0.010115
# 2       Q3    250 -0.010032  0.628894
# 3       Q4    250  0.634238  3.927528

# %%
results['quartile']
# Out:
# 0    Q1
# 1    Q2
# 2    Q3
# 3    Q4
# Name: quartile, dtype: category
# Categories (4, object): [Q1 < Q2 < Q3 < Q4]

# %%
N = 10000000
draws = pd.Series(np.random.randn(N))
labels = pd.Series(['foo', 'bar', 'baz', 'qux'] * (N // 4))
categories = labels.astype('category')
labels.memory_usage()
# Out:
# 80000080

# %%
482pages
